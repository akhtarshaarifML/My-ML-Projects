# %%
#Tensorboard is a visualization tool provided by TensorFlow
#It is used to visualize the training of neural networks
#It is very useful to debug the training process
#It can be used to visualize the training and validation loss, accuracy, etc.
#It can also be used to visualize the computation graph of the neural network
#It can also be used to visualize the weights and biases of the neural network
#It can also be used to visualize the output of the neural network
#It can also be used to visualize the gradients of the neural network
#It can also be used to visualize the activations of the neural network
#It can also be used to visualize the images, audio, text, etc.
#It can also be used to visualize the embeddings of the neural network
#It can also be used to visualize the hyperparameters of the neural network
#It can also be used to visualize the custom data
#It can also be used to visualize the custom metrics
#It can also be used to visualize the custom scalars
#It can also be used to visualize the custom histograms
#It can also be used to visualize the custom images
#It can also be used to visualize the custom audio
#It can also be used to visualize the custom text
#It can also be used to visualize the custom graph
#It can also be used to visualize the custom projector
#It can also be used to visualize the custom profile
#It can also be used to visualize the custom time series
#It can also be used to visualize the custom PR curve
#It can also be used to visualize the custom ROC curve
#It can also be used to visualize the custom confusion matrix
#It can also be used to visualize the custom distribution
#It can also be used to visualize the custom embedding
#It can also be used to visualize the custom plugin
#It can also be used to visualize the custom debugger
#It can also be used to visualize the custom profiler
#It can also be used to visualize the custom trace
#It can also be used to visualize the custom memory
#etc etc...
#It is very useful to debug the training process
#It is very useful to optimize the training process
#It is very useful to optimize the neural network

# %%
import pandas as pd
import numpy as np

# %%
import os
current_dir = os.getcwd()
print(current_dir)
# Out:
# /Users/shaarifakhtar/Documents/python/python basics

# %%
#Reading the dataset
df = pd.read_csv('cancer_classification.csv')

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %% [markdown]
# Breast Cancer Data Set
#
# This dataset contains the characteristics of patients diagnosed with cancer. The dataset contains the type of cancer (diagnosis), the visual characteristics of the cancer and the average values of these characteristics.
# The main features of the dataset are as follows:
#
# id: Represents a unique ID of each patient. (removed from the csv file already because it is not relevant to analysis)
# diagnosis: Indicates the type of cancer. This property can take the values "M" (Malignant - Benign) or "B" (Benign - Malignant).
# radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean: Represents the mean values of the cancer's visual characteristics.
# There are also several categorical features where patients in the dataset are labeled with numerical values. You can examine them in the Chart area.
#
# Other features contain specific ranges of average values of the features of the cancer image:
#
# radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean
# Each of these features is mapped to a table containing the number of values in a given range.
#
# Each sample contains the patient's unique ID(removed from this dataset), the cancer diagnosis and the average values of the cancer's visual characteristics.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


df.corr()['benign_0__mal_1'][:-1].sort_values().plot(kind='bar')
plt.show()

#Finding which features are most correlated with the target 
# variable that is 'benign_0__mal_1'

# %%
cor_data = df.corr()['benign_0__mal_1'][:-1].sort_values()[:13]

#extract feature names from this 
#and then use these feature names to plot the heatmap
#to see the correlation between these features

#Get first column of this dataframe 
#which is the feature names
feature_names = cor_data.index.values
print(feature_names)

sns.heatmap(df[feature_names].corr(numeric_only=True), cmap='coolwarm',  annot=True)

plt.show()
plt.close()
#observe the correlation between these features
#The lowest correlation is between 'worst compactness' and 'radius error' = 0.29
# Out:
# ['worst concave points' 'worst perimeter' 'mean concave points'
#  'worst radius' 'mean perimeter' 'worst area' 'mean radius' 'mean area'
#  'mean concavity' 'worst concavity' 'mean compactness' 'worst compactness'
#  'radius error']

# %%
correlation_values = df[['radius error', 'worst compactness', 'benign_0__mal_1']].corr()['benign_0__mal_1']
print(correlation_values)

#The correlations with target variable are pretty high.
# Out:
# radius error        -0.567134
# worst compactness   -0.590998
# benign_0__mal_1      1.000000
# Name: benign_0__mal_1, dtype: float64

# %%
#lets make a scatter plot of target feature with these two features
plt.scatter(df['radius error'], df['worst compactness'], 
            c=df['benign_0__mal_1'], cmap='coolwarm', alpha=0.5)
plt.xlabel('radius error')
plt.ylabel('worst compactness') 
plt.title('Scatter Plot of Radius Error vs Worst Compactness')
plt.colorbar(label='Benign (0) or Malignant (1)')
#Plot a line between the two points
x = np.linspace(0, 0.7,100)
y = np.linspace(0.6, 0,100)
plt.plot(x, y, 'r', label='Decision Boundary')
plt.grid(True)
plt.legend()
plt.show()

#There seems to be a linear separation between the two classes

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
import tensorflow as tf
import datetime

# %%
# Clear any logs from previous runs
# !rm -rf ./logs/

# %%
#Train Test Split
X= df.drop('benign_0__mal_1',axis=1).values
y= df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, 
                                                    random_state=101)

# %%
#Lets scale the data

from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#Building the model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout, Activation

# %%
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25) 
#patience is the number of epochs with no improvement after 
# which training will be stopped

# %%
#Tracking the current directory

import os 
os.getcwd()
# Out:
# '/Users/shaarifakhtar/Documents/python/python basics'

# %% [markdown]
# Creating the Tensorboard Callback
# This callback logs events for TensorBoard, including:
# * Metrics summary plots
# * Training graph visualization
# * Activation histograms
# * Sampled profiling
#
# If you have installed TensorFlow with pip, you should be able
# to launch TensorBoard from the command line:
#
# ```sh
# tensorboard --logdir=/Users/shaarifakhtar/Documents/python/python basics
# You can find more information about TensorBoard
# [here](https://www.tensorflow.org/tensorboard/).
#
#     Arguments:
#         log_dir: the path of the directory where to save the log files to be
#           parsed by TensorBoard.
#         histogram_freq: frequency (in epochs) at which to compute activation and
#           weight histograms for the layers of the model. If set to 0, histograms
#           won't be computed. Validation data (or split) must be specified for
#           histogram visualizations.
#         write_graph: whether to visualize the graph in TensorBoard. The log file
#           can become quite large when write_graph is set to True.
#         write_images: whether to write model weights to visualize as image in
#           TensorBoard.
#           update_freq: `'batch'` or `'epoch'` or integer. When using `'batch'`,
#           writes the losses and metrics to TensorBoard after each batch. The same
#           applies for `'epoch'`. If using an integer, let's say `1000`, the
#           callback will write the metrics and losses to TensorBoard every 1000
#           samples. Note that writing too frequently to TensorBoard can slow down
#           your training.
#         profile_batch: Profile the batch to sample compute characteristics. By
#           default, it will profile the second batch. Set profile_batch=0 to
#           disable profiling. Must run in TensorFlow eager mode.
#         embeddings_freq: frequency (in epochs) at which embedding layers will
#           be visualized. If set to 0, embeddings won't be visualized.

# %%
from datetime import datetime

# %%
datetime.now().strftime("%Y-%m-%d--%H%M")
# Out:
# '2025-02-19--1715'

# %%
# WINDOWS: Use "logs\\fit"
# MACOS/LINUX: Use "logs\fit"

log_directory = "logs/fit"
board = TensorBoard(log_dir=log_directory,histogram_freq=1,
                    write_graph=True,
                    write_images=True,
                    update_freq='epoch',
                    profile_batch=2,
                    embeddings_freq=1)
#What did we do here?
#We created a TensorBoard object called board
#We passed the log_directory to the log_dir parameter,etc
# Out:
# 2025-02-19 17:15:37.621468: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:103] Profiler session initializing.
# 2025-02-19 17:15:37.621495: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:118] Profiler session started.
# 2025-02-19 17:15:37.623138: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:130] Profiler session tear down.

# %%
#Lets build the model
#As data is linearly separable, we can consider just one hidden layer
model = Sequential()
model.add(Dense(30, activation='relu')) #input layer
model.add(Dropout(0.5)) #Dropout layer
model.add(Dense(15, activation='relu')) #hidden layer
model.add(Dropout(0.5)) #Dropout layer
model.add(Dense(1, activation='sigmoid')) #output layer
model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
#Lets train the model
history = model.fit(x=X_train, y=y_train, epochs=600, validation_data=(X_test, y_test), 
          callbacks=[early_stop, board], verbose=1, batch_size=256)
# Out:
# Epoch 1/600
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 187ms/step - loss: 0.7112 - val_loss: 0.6936
# Epoch 2/600
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6988
# 2025-02-19 17:15:46.795488: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:103] Profiler session initializing.
# 2025-02-19 17:15:46.795499: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:118] Profiler session started.
# 2025-02-19 17:15:46.798408: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:68] Profiler session collecting data.
# 2025-02-19 17:15:46.802203: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:130] Profiler session tear down.
# 2025-02-19 17:15:46.805364: I external/local_xla/xla/tsl/profiler/rpc/client/save_profile.cc:147] Collecting XSpace to repository: logs/fit/train/plugins/profile/2025_02_19_17_15_46/Shaarifs-MacBook-Air.local.xplane.pb
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.7036 - val_loss: 0.6915
# Epoch 3/600
# ...

# %%
losses = model.history.history
losses = pd.DataFrame(losses)
losses.plot()

#loss and validation loss are decreasing
#This means that the model is learning
#The model is not overfitting
# Out:
# <Axes: >

# %%
#Making predictions from the testing data
predictions = (model.predict(X_test)>0.5).astype('int32')
prediction_df = pd.DataFrame({'predictions': predictions.reshape(-1), 'True value': y_test})
print(prediction_df.head())
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#    predictions  True value
# 0            1           1
# 1            1           1
# 2            1           1
# 3            0           0
# 4            1           1

# %%
#Lets evaluate the model
from sklearn.metrics import classification_report, confusion_matrix 

classification_report_result = classification_report(y_test, predictions)
confusion_matrix_result = confusion_matrix(y_test, predictions)

print('Classification Report:\n', classification_report_result)
print('Confusion Matrix:\n', confusion_matrix_result)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95        55
#            1       0.98      0.97      0.97        88
#
#     accuracy                           0.97       143
#    macro avg       0.96      0.96      0.96       143
# weighted avg       0.97      0.97      0.97       143
#
# Confusion Matrix:
#  [[53  2]
#  [ 3 85]]

# %%
#Hence we have built a neural network model to classify the cancer data
#The model is performing well
#Now we address the elephant in the room
#How to visualize the training of the neural network
#We can use TensorBoard for this purpose

# %%
print(log_directory)
# Out:
# logs/fit

# %%
Start TensorBoard through the command line or within a notebook experience. 
The two interfaces are generally the same. In notebooks, use the `%tensorboard` line magic. 
On the command line, run the same command without "%".

# %%
# %tensorboard --logdir logs/fit
# Out:
#       <iframe id="tensorboard-frame-54e38a0f8cf37c76" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-54e38a0f8cf37c76");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# A brief overview of the visualizations created in this example and the dashboards (tabs in top navigation bar) where they can be found:
#
# * **Scalars** show how the loss and metrics change with every epoch. You can use them to also track training speed, learning rate, and other scalar values. Scalars can be found in the **Time Series** or **Scalars** dashboards.
# * **Graphs** help you visualize your model. In this case, the Keras graph of layers is shown which can help you ensure it is built correctly. Graphs can be found in the **Graphs** dashboard.
# * **Histograms** and **Distributions** show the distribution of a Tensor over time. This can be useful to visualize weights and biases and verify that they are changing in an expected way. Histograms can be found in the **Time Series** or **Histograms** dashboards. Distributions can be found in the **Distributions** dashboard.
#
# Additional TensorBoard dashboards are automatically enabled when you log other types of data. For example, the Keras TensorBoard callback lets you log images and embeddings as well. You can see what other dashboards are available in TensorBoard by clicking on the "inactive" dropdown towards the top right.

# %% [markdown]
# Running Tensorboard
# Tensorboard will run locally in your browser at [http://localhost:6006/](http://localhost:6006/)
